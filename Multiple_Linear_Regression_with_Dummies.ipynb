# %% [markdown]
# # Multiple Linear Regression with Dummies

# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns

# Configurar el estilo de las gráficas con seaborn
sns.set()

# %% [markdown]
# ## Load the data

# %%
# Leer los datos desde el archivo CSV
raw_data = pd.read_csv('real_estate_price_size_year_view.csv')

# %%
# Visualizar las primeras filas del DataFrame para entender su estructura
raw_data.head()
# Out:
#         price     size  year         view
# 0  234314.144   643.09  2015  No sea view
# 1  228581.528   656.22  2009  No sea view
# 2  281626.336   487.29  2018     Sea view
# 3  401255.608  1504.75  2015  No sea view
# 4  458674.256  1275.46  2009     Sea view

# %%
# Obtener estadísticas descriptivas del DataFrame
raw_data.describe(include='all')
# Out:
#                 price         size         year         view
# count      100.000000   100.000000   100.000000          100
# unique            NaN          NaN          NaN            2
# top               NaN          NaN          NaN  No sea view
# freq              NaN          NaN          NaN           51
# mean    292289.470160   853.024200  2012.600000          NaN
# std      77051.727525   297.941951     4.729021          NaN
# min     154282.128000   479.750000  2006.000000          NaN
# 25%     234280.148000   643.330000  2009.000000          NaN
# 50%     280590.716000   696.405000  2015.000000          NaN
# 75%     335723.696000  1029.322500  2018.000000          NaN
# max     500681.128000  1842.510000  2018.000000          NaN

# %% [markdown]
# ## Create a dummy variable for 'view'

# %%
# Copiar los datos para evitar modificar el conjunto de datos original
data = raw_data.copy()

# Mapear la variable 'view' a valores numéricos (0 para 'No sea view', 1 para 'Sea view')
data['view'] = data['view'].map({'Sea view': 1, 'No sea view': 0})

# %%
# Visualizar las primeras filas del DataFrame modificado
data.head()
# Out:
#         price     size  year  view
# 0  234314.144   643.09  2015     0
# 1  228581.528   656.22  2009     0
# 2  281626.336   487.29  2018     1
# 3  401255.608  1504.75  2015     0
# 4  458674.256  1275.46  2009     1

# %% [markdown]
# ## Create the regression

# %% [markdown]
# ### Declare the dependent and the independent variables

# %%
# Definir la variable dependiente y las variables independientes
y = data['price']
x1 = data[['size', 'year', 'view']]

# %% [markdown]
# ### Regression

# %%
# Añadir una columna de unos (constantes) a la matriz de características
x = sm.add_constant(x1)

# Ajustar un modelo de regresión lineal utilizando OLS (Mínimos Cuadrados Ordinarios)
results = sm.OLS(y, x).fit()

# Mostrar un resumen detallado de los resultados del modelo de regresión lineal
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.913
# Model:                            OLS   Adj. R-squared:                  0.910
# Method:                 Least Squares   F-statistic:                     335.2
# Date:                Sat, 27 Apr 2024   Prob (F-statistic):           1.02e-50
# Time:                        10:07:16   Log-Likelihood:                -1144.6
# No. Observations:                 100   AIC:                             2297.
# Df Residuals:                      96   BIC:                             2308.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5.398e+06   9.94e+05     -5.431      0.000   -7.37e+06   -3.43e+06
# ...
